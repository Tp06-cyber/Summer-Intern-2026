# %%
name = input("Enter student name: ")
student_class = input("Enter class: ")

mark1 = int(input("Enter marks of Subject 1: "))
mark2 = int(input("Enter marks of Subject 2: "))
mark3 = int(input("Enter marks of Subject 3: "))
mark4 = int(input("Enter marks of Subject 4: "))
mark5 = int(input("Enter marks of Subject 5: "))

total = mark1 + mark2 + mark3 + mark4 + mark5
percentage = total / 5
print("Name:", name)
print("Class:", student_class)
print("Total Marks:", total)
print("Percentage:", percentage, "%")
# Out:
# Name: Tanish
# Class: 12
# Total Marks: 210
# Percentage: 42.0 %

# %%
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")
result = str1 + " " + str2
print("lower():", result.lower())
print("upper():", result.upper())
print("title():", result.title())
print("swapcase():", result.swapcase())
print("capitalize():", result.capitalize())
print("casefold():", result.casefold())
print("center():", result.center(50))
print("count('a'):", result.count('a'))
print("endswith('a'):", result.endswith('a'))
print("find('a'):", result.find('a'))
print("isalnum():", result.isalnum())
print("isdigit():", result.isdigit())
print("isnumeric():", result.isnumeric())
print("isspace():", result.isspace())
print("replace('a','@'):", result.replace('a', '@'))
# Out:
# lower(): tanish python
# upper(): TANISH PYTHON
# title(): Tanish Python
# swapcase(): tANISH pYTHON
# capitalize(): Tanish python
# casefold(): tanish python
# center():                   Tanish Python
# count('a'): 1
# endswith('a'): False
# find('a'): 1
# isalnum(): False
# isdigit(): False
# isnumeric(): False
# isspace(): False
# replace('a','@'): T@nish Python

# %%
name = input("Enter student name: ")
student_class = input("Enter class: ")

mark1 = int(input("Enter marks of Subject 1: "))
mark2 = int(input("Enter marks of Subject 2: "))
mark3 = int(input("Enter marks of Subject 3: "))
mark4 = int(input("Enter marks of Subject 4: "))
mark5 = int(input("Enter marks of Subject 5: "))

total = mark1 + mark2 + mark3 + mark4 + mark5
percentage = total / 5

if percentage >= 60:
    grade = 'A'
elif percentage >= 50:
    grade = 'B'
elif percentage >= 40:
    grade = 'C'
elif percentage >= 33:
    grade = 'D'
else:
    grade = 'Fail'

print("\n----- Result -----")
print("Name:", name)
print("Class:", student_class)
print("Total Marks:", total)
print("Percentage:", percentage, "%")
print("Grade:", grade)
