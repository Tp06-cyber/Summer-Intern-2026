# %%
m=int(input("Enter MArks"))
if m>75:
    print("Grade A")
elif m>60:
    print("Grade B")
elif m>50:
    print("Grade C")
else:
    print("Try again")
# Out:
# Grade A

# %%
l=[1,2,3,4]
print(l[-2],type(l))
# Out:
# 3 <class 'list'>

# %%
l=[1,2,3,4]
print(l[0::3],type(l))
print(sum(l[0:5]))
print(max(l[0:5]))
# Out:
# [1, 4] <class 'list'>
# 10
# 4

# %%
st=[1,2,3,4]
print(st)
st.extend(["Tanish","Pinjani"])
print(st)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4, 'Tanish', 'Pinjani']

# %%
while(True):
    print("""
        1. Add element to queue
        2. Remove element from  Queue
        3. Display First three Element
        4. Display Last three Element
        5. Print
        6. Exit
          """)
    ch = int(input("Enter Your Choice"))
    if ch==1:
        pass
    elif ch==2:
        pass
    elif ch==3:
        pass
    elif ch==4:
        pass
    elif ch==5:
        pass
    elif ch==6:
        break
    else: print("Invalid Choise")
# Out:
#         1. Add element to queue
#         2. Remove element from  Queue
#         3. Display First three Element
#         4. Display Last three Element
#         5. Print
#         6. Exit
#
#
#         1. Add element to queue
#         2. Remove element from  Queue
#         3. Display First three Element
#         4. Display Last three Element
#         5. Print
#         6. Exit
#
#
#         1. Add element to queue
#         2. Remove element from  Queue
#         3. Display First three Element
#         4. Display Last three Element
#         5. Print
#         6. Exit
#
#
#         1. Add element to queue
#         2. Remove element from  Queue
#         3. Display First three Element
#         4. Display Last three Element
#         5. Print
#         6. Exit
#
# Invalid Choise
#
#         1. Add element to queue
#         2. Remove element from  Queue
#         3. Display First three Element
#         4. Display Last three Element
#         5. Print
#         6. Exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 10
#       6         4. Display Last three Element
#       7         5. Print
#       8         6. Exit
#       9           """)
# ---> 10     ch=int(input("Enter Your Choice"))
#      11     if ch==1:
#      12         pass
#      13     elif ch==2:
#
# ValueError: invalid literal for int() with base 10: ''
